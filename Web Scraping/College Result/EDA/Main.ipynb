# %%
import  pandas as pd
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('final.csv')
df
# Out:
#        Seat No                              Name                 Mother Name  \
# 0   B190784201             AGALE TEJASHRI SANJAY          AGALE NANDA SANJAY
# 1   B190784202           AHIRE DARSHAN RAGHUNATH      AHIRE SAVITA RAGHUNATH
# 2   B190784203                  ANIKET RANDHAVAN    MANGAL PRAKASH RANDHAVAN
# 3   B190784204           ANTRE PRATIBHA RAKHAMA                      MANISHA
# 4   B190784205           AUTADE ANUSHKA RAVINDRA                      SAVITA
# 5   B190784206          BACHKAR TEJASHRI SHIVAJI                        ALKA
# 6   B190784207              BAGALE RUTWIK DEELIP       BAGALE KANCHAN DEELIP
# 7   B190784208          BORKAR SHUBHAM BALASAHEB                      SAVITA
# 8   B190784209          CHEMATE AISHWARYA SANJAY                      SHARDA
# 9   B190784210   CHINTANWAR VAISHNAVI RAMCHANDRA                       REENA
# 10  B190784211               CHOWGULE VIVEK ARUN       CHOWGULE SANGITA ARUN
# ...

# %%
# fill null and na
df.fillna(0, inplace=True)
df
# Out:
#        Seat No                              Name                 Mother Name  \
# 0   B190784201             AGALE TEJASHRI SANJAY          AGALE NANDA SANJAY
# 1   B190784202           AHIRE DARSHAN RAGHUNATH      AHIRE SAVITA RAGHUNATH
# 2   B190784203                  ANIKET RANDHAVAN    MANGAL PRAKASH RANDHAVAN
# 3   B190784204           ANTRE PRATIBHA RAKHAMA                      MANISHA
# 4   B190784205           AUTADE ANUSHKA RAVINDRA                      SAVITA
# 5   B190784206          BACHKAR TEJASHRI SHIVAJI                        ALKA
# 6   B190784207              BAGALE RUTWIK DEELIP       BAGALE KANCHAN DEELIP
# 7   B190784208          BORKAR SHUBHAM BALASAHEB                      SAVITA
# 8   B190784209          CHEMATE AISHWARYA SANJAY                      SHARDA
# 9   B190784210   CHINTANWAR VAISHNAVI RAMCHANDRA                       REENA
# 10  B190784211               CHOWGULE VIVEK ARUN       CHOWGULE SANGITA ARUN
# ...

# %%
SGPA_TOP = df.sort_values(by='SGPA', ascending=False)
CGPA_TOP=df.sort_values(by='CGPA',ascending=False)

# %%
SGPA_TOP
# Out:
#        Seat No                              Name                 Mother Name  \
# 62  B190784263            SANKPAL ASHLESHA ANANT                    JAYSHRI
# 63  B190784264  SARPANCHAL SOURABH SHARADCHANDRA           APARNA SARPANCHAL
# 61  B190784262                SALE DIVYA TUKARAM                       GEETA
# 5   B190784206          BACHKAR TEJASHRI SHIVAJI                        ALKA
# 65  B190784266         SHINDE RISHIKESH DNYANDEV                     MANISHA
# 69  B190784270          SWAMI VAISHNAVI NILKAMAL                       REKHA
# 49  B190784250            PAGAR SPANDAN RAJENDRA        JYOTI RAJENDRA PAGAR
# 3   B190784204           ANTRE PRATIBHA RAKHAMA                      MANISHA
# 18  B190784219               GHADGE AKASH SURESH                        LATA
# 58  B190784259               RAKSHE SNEHA KAILAS                      ROHINI
# 4   B190784205           AUTADE ANUSHKA RAVINDRA                      SAVITA
# ...

# %%
CGPA_TOP
# Out:
#        Seat No                              Name                 Mother Name  \
# 61  B190784262                SALE DIVYA TUKARAM                       GEETA
# 9   B190784210   CHINTANWAR VAISHNAVI RAMCHANDRA                       REENA
# 39  B190784240                KHARAT ROHIT SUNIL        KHARAT RANJANA SUNIL
# 63  B190784264  SARPANCHAL SOURABH SHARADCHANDRA           APARNA SARPANCHAL
# 66  B190784267      SHIRKE RUTUJA CHANDRASHEKHAR                    PRATIBHA
# 27  B190784228           JATHAR KISHORI RAVINDRA       ANITA RAVINDRA JATHAR
# 3   B190784204           ANTRE PRATIBHA RAKHAMA                      MANISHA
# 60  B190784261              RAUT PRANAV SADASHIV       RAUT NIRMALA SADASHIV
# 18  B190784219               GHADGE AKASH SURESH                        LATA
# 43  B190784244          MATSAGAR KISHOR PRALHAD      CHHAYA PRALHAD MATSAGAR
# 65  B190784266         SHINDE RISHIKESH DNYANDEV                     MANISHA
# ...
